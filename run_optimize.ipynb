# %%
from optimizers import *
# Out:
# /Users/arvingopal5794/anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# # Optimize 2 layer net for kernel size and patch size

# %%
subset_size = 50
optimize_kernel_and_patch(subset_size, k_fold = 5)

# %% [markdown]
# # Now optimize for number of epochs and 1st layer depth

# %%
subset_size = 50
optimize_num_epochs(subset_size, 5)

# %% [markdown]
# # Finally optimize hyperparam in 2 layer net

# %%
subset_size = 5
optimize_hyperparam(subset_size, 1)
# Out:
# Momentum is 0.0
# Learning rate is 0.0001
# Current k-fold index is 1
# File /Users/arvingopal5794/Downloads/training/images/satImage_001.png does not exist
# File /Users/arvingopal5794/Downloads/training/images/satImage_002.png does not exist
# File /Users/arvingopal5794/Downloads/training/images/satImage_003.png does not exist
# File /Users/arvingopal5794/Downloads/training/images/satImage_004.png does not exist
# File /Users/arvingopal5794/Downloads/training/images/satImage_005.png does not exist
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-ec1c4cd87cba> in <module>()
#       1 subset_size = 5
# ----> 2 optimize_hyperparam(subset_size, 1)
#
# /Users/arvingopal5794/project_2/optimizers.py in optimize_hyperparam(subset_size, k_fold)
#      93             for j in range(k_fold):
#      94                 print ("Current k-fold index is", j+1)
# ---> 95                 e = main(subset_size,kernel_size,strides,depth_1st_layer, patch_size, num_epochs, i, k, j + 1, k_fold)
#      96                 print ("This error -", e, "- will be used in cross validation")
#      97                 errs.append(e)
#
# /Users/arvingopal5794/project_2/tf_optimize_2layers.py in main(t_size, filter_size, strides, num_filters, patch_size, num_epochs, mom, base_rate, k_fold_index, k_fold)
#     200     train_labels_filename = data_dir + 'training/groundtruth/'
#     201
# --> 202     train_data = extract_data_opt(train_data_filename, TRAINING_SIZE, IMG_PATCH_SIZE, k_fold_index, k_fold)
#     203     train_labels = extract_labels_opt(train_labels_filename, TRAINING_SIZE, IMG_PATCH_SIZE, k_fold_index, k_fold)
#     204
#
# /Users/arvingopal5794/project_2/tf_optimize_2layers.py in extract_data_opt(filename, num_images, IMG_PATCH_SIZE, k_fold_index, k_fold)
#      73
#      74     num_images = len(imgs)
# ---> 75     IMG_WIDTH = imgs[0].shape[0]
#      76     IMG_HEIGHT = imgs[0].shape[1]
#      77     N_PATCHES_PER_IMAGE = (IMG_WIDTH/IMG_PATCH_SIZE)*(IMG_HEIGHT/IMG_PATCH_SIZE)
#
# IndexError: list index out of range
